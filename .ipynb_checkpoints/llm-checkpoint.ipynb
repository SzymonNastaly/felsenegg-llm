# %%
import torch

if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

# %%
import urllib.request
import os
url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
file_path = "dataset.txt"

if not os.path.exists(file_path):
    urllib.request.urlretrieve(url, file_path)

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3 url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
#       4 file_path = "dataset.txt"
#       5
#       6 if not os.path.exists(file_path):
# ----> 7     urllib.requests.urlretrieve(url, file_path)
#       8
#       9 with open(file_path, "r", encoding="utf-8") as f:
#      10     text = f.read()
#
# AttributeError: module 'urllib' has no attribute 'requests'
