# %%
import torch
from bpe import BPETokenizer

if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

# %%
import urllib.request
import os
url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
file_path = "dataset.txt"

if not os.path.exists(file_path):
    urllib.request.urlretrieve(url, file_path)

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

# %%
TARGET_VOCAB = 512
tokenizer = BPETokenizer()
tokenizer.train(text, TARGET_VOCAB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 TARGET_VOCAB = 512
#       2 tokenizer = BPETokenizer()
# ----> 3 tokenizer.train(text, TARGET_VOCAB)
#
# File ~/projects/llm-from-scratch/bpe.py:40, in BPETokenizer.train(self, text, target_vocab_size)
#      38     new_token_ids = []
#      39     for chunk in token_ids:
# ---> 40         new_token_ids.append(BPETokenizer._merge_pair(chunk,best_pair))
#      41     token_ids = new_token_ids
#      43 special_tokens = ["<|eos|>"]
#
# File ~/projects/llm-from-scratch/bpe.py:76, in BPETokenizer._merge_pair(token_ids, pair)
#      74 while j < len(token_ids):
#      75     if j < len(token_ids)-1 and (token_ids[j],token_ids[j+1]) == pair:
# ---> 76         new_chunk.append(new_token_id)
#      77         j+=2
#      78     else:
#
# NameError: name 'new_token_id' is not defined

# %%
tokenizer.encode("Hello, my name is Szymon")
